# %% [markdown]
# <a href="https://colab.research.google.com/github/MritulaC/100-Days-Of-ML-Code/blob/master/TimeGanCSVData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TIME GAN
#
# URL: https://github.com/numancelik34/TimeSeries-GAN/blob/master/conv1d_gan.py

# %%
# !git clone https://github.com/numancelik34/TimeSeries-GAN.git
# Out:
# Cloning into 'TimeSeries-GAN'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 18 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), done.

# %%
# !ls -la
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Jan 12 07:17 .
# drwxr-xr-x 1 root root 4096 Jan 12 07:11 ..
# drwxr-xr-x 4 root root 4096 Jan  7 14:33 .config
# drwxr-xr-x 1 root root 4096 Jan  7 14:33 sample_data
# drwxr-xr-x 3 root root 4096 Jan 12 07:17 TimeSeries-GAN

# %%
# !pwd
# Out:
# /content

# %%
# %cd TimeSeries-GAN
# Out:
# /content/TimeSeries-GAN

# %%
# !ls -la
# Out:
# total 2332
# drwxr-xr-x 3 root root    4096 Jan 12 07:17 .
# drwxr-xr-x 1 root root    4096 Jan 12 07:17 ..
# -rw-r--r-- 1 root root   11149 Jan 12 07:17 conv1d_gan.py
# drwxr-xr-x 8 root root    4096 Jan 12 07:17 .git
# -rw-r--r-- 1 root root 2356325 Jan 12 07:17 outfinaltest890.csv
# -rw-r--r-- 1 root root    1194 Jan 12 07:17 README.md

# %%
# !python conv1d_gan.py
# Out:
# 2022-01-12 07:29:53.296394: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 384, 1)]     0           []
#
#  conv1d (Conv1D)                (None, 192, 16)      64          ['input_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 192, 16)      0           ['conv1d[0][0]']
#
#  dropout (Dropout)              (None, 192, 16)      0           ['leaky_re_lu[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 96, 32)       1568        ['dropout[0][0]']
#
# ...
